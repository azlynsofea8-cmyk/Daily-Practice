# %%
import numpy as np

# %%
array1 = np.array([1,2,3])

# %%
# create one class 
# one attribte save name
# one method welcome(name): return f"Welcome {name}!!!"

class names:
    def __init__(self,name):
        self.name = name

    def welcome(self):
        return f"Welcome {self.name}!!!"

user = Names("Muhammad Ali")
user.welcome()

# %%
user = Names("Muhammad Ali")
print(user.welcome())

# %%
from mypkg.newfun import funthings as nf

# %%
nf.welcome("Ali")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 nf.welcome("Ali")
#
# AttributeError: module 'mypkg.newfun.funthings' has no attribute 'welcome'
